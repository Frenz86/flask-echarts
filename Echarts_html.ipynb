# %%
######### EPLOT ###############àà

# %%
# !pip install pyecharts-javascripthon
# Out:
# Collecting pyecharts-javascripthon
#   Downloading https://files.pythonhosted.org/packages/6f/68/23644a394341fef4cbcb48a3fa4b2816408a13a1fa3281cf9030b2ac2d67/pyecharts_javascripthon-0.0.6-py2.py3-none-any.whl
# Collecting javascripthon>=0.10; python_version > "3.4"
#   Downloading https://files.pythonhosted.org/packages/b2/6d/e8339cae8487b8a226d9fcc25804697bcbcdf2c0b46f879f3de36d124887/javascripthon-0.11.tar.gz (540kB)
#      |████████████████████████████████| 542kB 4.1MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from javascripthon>=0.10; python_version > "3.4"->pyecharts-javascripthon) (46.1.3)
# Collecting dukpy
#   Downloading https://files.pythonhosted.org/packages/32/01/9690b743bb058559b91e1e290bad4bda68d7bc572bc1c06c77c664161436/dukpy-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (2.0MB)
#      |████████████████████████████████| 2.0MB 24.8MB/s
# Collecting macropy3==1.1.0b2
#   Downloading https://files.pythonhosted.org/packages/8c/b7/a61f9d9bd7de80ca51ef362db5bb6434ea21484c907d2a5f396d97b0274c/macropy3-1.1.0b2.tar.gz (44kB)
#      |████████████████████████████████| 51kB 5.7MB/s
# Building wheels for collected packages: javascripthon, macropy3
#   Building wheel for javascripthon (setup.py) ... done
#   Created wheel for javascripthon: filename=javascripthon-0.11-cp36-none-any.whl size=526625 sha256=e7c95bf6626c7f3755285ff731bebd5a044a6082752b005c1d578be9e4990790
#   Stored in directory: /root/.cache/pip/wheels/31/18/7e/bd39eb1de4f3128eba5c0d8bfd8bbc2fd07f6c715b6406c30a
#   Building wheel for macropy3 (setup.py) ... done
#   Created wheel for macropy3: filename=macropy3-1.1.0b2-cp36-none-any.whl size=50111 sha256=ebc71184ef019d87fbdf32b10c7945c31c64deecee259a66823663a43c18c2c2
#   Stored in directory: /root/.cache/pip/wheels/ef/ea/95/65744a6a720d5b0b57779da564c68a3e1b221ea998542a78b3
# Successfully built javascripthon macropy3
# Installing collected packages: dukpy, macropy3, javascripthon, pyecharts-javascripthon
# Successfully installed dukpy-0.2.2 javascripthon-0.11 macropy3-1.1.0b2 pyecharts-javascripthon-0.0.6

# %%
# !pip install pyecharts
# !pip install eplot
# Out:
# Requirement already satisfied: pyecharts in /usr/local/lib/python3.6/dist-packages (1.7.1)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.6/dist-packages (from pyecharts) (0.7.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from pyecharts) (2.11.1)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.6/dist-packages (from pyecharts) (3.17.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->pyecharts) (1.1.1)
# Collecting eplot
#   Downloading https://files.pythonhosted.org/packages/b2/09/e08ce60ac324943dc1fd80a2f730b0ba6c48832e766e06006a6f289739fd/eplot-0.1.2.tar.gz
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from eplot) (1.0.3)
# Requirement already satisfied: pyecharts in /usr/local/lib/python3.6/dist-packages (from eplot) (1.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from eplot) (1.18.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas->eplot) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->eplot) (2018.9)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from pyecharts->eplot) (2.11.1)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.6/dist-packages (from pyecharts->eplot) (3.17.0)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.6/dist-packages (from pyecharts->eplot) (0.7.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas->eplot) (1.12.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->pyecharts->eplot) (1.1.1)
# Building wheels for collected packages: eplot
#   Building wheel for eplot (setup.py) ... done
#   Created wheel for eplot: filename=eplot-0.1.2-cp36-none-any.whl size=3608 sha256=de5b46de18d3dbb43ceea4503f19def3a09bfea1644aee3b6068a247d2c0e82c
#   Stored in directory: /root/.cache/pip/wheels/83/58/08/e312b4f138f306b0df52cde0a41bd446472c5c8971e7e10eb1
# Successfully built eplot
# Installing collected packages: eplot
# Successfully installed eplot-0.1.2

# %% [markdown]
# ### REACT APP WITH ECHARTS

# %%
# React app with echarts
#https://medium.com/@mailjontay/make-a-dynamic-chart-with-react-and-echarts-a-simple-tutorial-92a5c3c053a2

## Google sheet to react
#https://www.developintelligence.com/blog/2018/08/the-simple-stack-a-primer-on-using-react-google-sheets-api/
#https://levelup.gitconnected.com/google-sheets-api-tutorial-with-javascript-588f581aa1d9

# %% [markdown]
# ### ECHARTS WITH PANDAS DATAFRAME

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
import pandas as pd

df = pd.DataFrame({'x':[1,2,3], 'y':[4,2,6]})

bar = Bar()
bar.add_xaxis(list(df.x))
bar.add_yaxis("variabile_y", list(df.y))
bar.set_global_opts(title_opts=opts.TitleOpts(title="TITOLO"))
bar.render()

display(HTML('render.html'))
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#
# </head>
# <body>
#     <div id="a26c55f0d1a54a88a34e54f0b1f3153d" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_a26c55f0d1a54a88a34e54f0b1f3153d = echarts.init(
#             document.getElementById('a26c55f0d1a54a88a34e54f0b1f3153d'), 'white', {renderer: 'canvas'});
#         var option_a26c55f0d1a54a88a34e54f0b1f3153d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "variabile_y",
#             "data": [
#                 4,
#                 2,
#                 6
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "variabile_y"
#             ],
#             "selected": {
#                 "variabile_y": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 1,
#                 2,
#                 3
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "TITOLO",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_a26c55f0d1a54a88a34e54f0b1f3153d.setOption(option_a26c55f0d1a54a88a34e54f0b1f3153d);
#     </script>
# </body>
# </html>

# %% [markdown]
# ### Eplot-Jupyter

# %%
from eplot import eplot
df = pd.Series([11,10,6],index=[1,2,3])
plot = df.eplot.bar(title='柱形图')

# %% [markdown]
# Echarts - Flask

# %%
#!pip install pyecharts-javascripthon
from pyecharts.charts import Bar
from pyecharts_javascripthon.api import TRANSLATOR
from flask import Flask, render_template


REMOTE_HOST = "https://pyecharts.github.io/assets/js"

app = Flask(__name__)

df = pd.DataFrame({'x':[1,2,3], 'y':[4,2,6]})

@app.route("/")
def hello():
    _bar = bar_chart()
    javascript_snippet = TRANSLATOR.translate(_bar.options)
    return render_template(
        "pyecharts.html",
        chart_id=_bar.chart_id,
        host=REMOTE_HOST,
        renderer=_bar.renderer,
        my_width="100%",
        my_height=600,
        custom_function=javascript_snippet.function_snippet,
        options=javascript_snippet.option_snippet,
        script_list=_bar.get_js_dependencies(),
    )


def bar_chart():
    bar = Bar()
    bar.add_xaxis(list(df.x))
    bar.add_yaxis("variabile_y", list(df.y))
    bar.set_global_opts(title_opts=opts.TitleOpts(title="TITOLO"))
    return bar

# %%
from IPython.display import HTML
HTML("""
<div>ciao ciao</div>
""")
# Out:
# <div>ciao ciao</div>

# %%
##OPPURE %%html

# %%
# %%html
# <head>
#     <meta charset="utf-8">
#     <title>myProject</title>
#     <!-- import the bundle `lib/echarts.custom.js`. -->
#     <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
# </head>
# <body>
#     <div id="main" style="width: 600px;height:400px;"></div>
#     <script>
#
# ////////////////////////////////////////////////////
#
# 		// Render line chart and components.
# 		echarts.init(document.getElementById('main')).setOption({
# 			title: {text: 'Chart'},
# 			tooltip: {},
# 			toolbox: {
# 				feature: {
# 					dataView: {},
# 					saveAsImage: {
# 						pixelRatio: 2
# 					},
# 					restore: {}
# 				}
# 			},
# 			xAxis: {},
# 			yAxis: {},
# 			series: [{
# 				type: 'line',
# 				smooth: true,
# 				data: [[12, 5], [24, 20], [36, 36], [48, 10], [60, 10], [72, 20]]
# 			}]
# 		});
#
# ////////////////////////////////////////////////////////
# //////////////////////////////////////////
#
#     </script>
#     </script>
# </body>
# </html>
# Out:
# <head>
#     <meta charset="utf-8">
#     <title>myProject</title>
#     <!-- import the bundle `lib/echarts.custom.js`. -->
#     <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
# </head>
# <body>
#     <div id="main" style="width: 600px;height:400px;"></div>
#     <script>
#
# ////////////////////////////////////////////////////
#
# 		// Render line chart and components.
# 		echarts.init(document.getElementById('main')).setOption({
# 			title: {text: 'Chart'},
# 			tooltip: {},
# 			toolbox: {
# 				feature: {
# 					dataView: {},
# 					saveAsImage: {
# 						pixelRatio: 2
# 					},
# 					restore: {}
# 				}
# 			},
# 			xAxis: {},
# 			yAxis: {},
# 			series: [{
# 				type: 'line',
# 				smooth: true,
# 				data: [[12, 5], [24, 20], [36, 36], [48, 10], [60, 10], [72, 20]]
# 			}]
# 		});
#
# ////////////////////////////////////////////////////////
# //////////////////////////////////////////
#
#     </script>
#     </script>
# </body>
# </html>

# %%
# %%html
# <html>
# <head>
#     <meta charset="utf-8">
#     <title>myProject</title>
#     <!-- import the bundle `lib/echarts.custom.js`. -->
#     <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
# </head>
# <body>
#     <div id="main" style="width: 600px;height:400px;"></div>
#     <script>
#
# ////////////////////////////////////////////////////
# 		// Render line chart and components.
# 		echarts.init(document.getElementById('main')).setOption({
# 			title: {text: 'Chart'},
# 			tooltip: {},
# 			toolbox: {
# 				feature: {
# 					dataView: {},
# 					saveAsImage: {
# 						pixelRatio: 2
# 					},
# 					restore: {}
# 				}
# 			},
# 			xAxis: {
# 				type: 'category',
# 				data: ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
# 			},
# 			yAxis: {
# 				type: 'value'
# 			},
# 			series: [{
# 				data: [820, 932, 901, 934, 1290, 1330, 1320],
# 				type: 'line'
# 			}]
# 		});
#
#
#
#
#
#
# ////////////////////////////////////////////////////////
# //////////////////////////////////////////
#
#     </script>
#     </script>
# </body>
# </html>
# Out:
# <html>
# <head>
#     <meta charset="utf-8">
#     <title>myProject</title>
#     <!-- import the bundle `lib/echarts.custom.js`. -->
#     <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
# </head>
# <body>
#     <div id="main" style="width: 600px;height:400px;"></div>
#     <script>
#
# ////////////////////////////////////////////////////
# 		// Render line chart and components.
# 		echarts.init(document.getElementById('main')).setOption({
# 			title: {text: 'Chart'},
# 			tooltip: {},
# 			toolbox: {
# 				feature: {
# 					dataView: {},
# 					saveAsImage: {
# 						pixelRatio: 2
# 					},
# 					restore: {}
# 				}
# 			},
# 			xAxis: {
# 				type: 'category',
# 				data: ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
# 			},
# 			yAxis: {
# 				type: 'value'
# 			},
# 			series: [{
# 				data: [820, 932, 901, 934, 1290, 1330, 1320],
# 				type: 'line'
# 			}]
# 		});
#
#
#
#
#
#
# ////////////////////////////////////////////////////////
# //////////////////////////////////////////
#
#     </script>
#     </script>
# </body>
# </html>

# %%
# %%html
# <html>
# <head>
#     <meta charset="utf-8">
#     <title>myProject</title>
#     <!-- import the bundle `lib/echarts.custom.js`. -->
#     <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
# </head>
# <body>
#     <div id="main" style="width: 600px;height:400px;"></div>
#     <script>
#
# ////////////////////////////////////////////////////
#
# 		// Render line chart and components.
# 		echarts.init(document.getElementById('main')).setOption({
# 			title: {text: 'Chart'},
# 			tooltip: {},
# 			toolbox: {
# 				feature: {
# 					dataView: {},
# 					saveAsImage: {
# 						pixelRatio: 2
# 					},
# 					restore: {}
# 				}
# 			},
# 			xAxis: {
# 				type: 'category',
# 				boundaryGap: false,
# 				data: ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
# 			},
# 			yAxis: {
# 				type: 'value'
# 			},
# 			series: [{
# 				data: [820, 932, 901, 934, 1290, 1330, 1320],
# 				type: 'line',
# 				areaStyle: {}
# 			}]
# 		});
#
#
#
#
# ////////////////////////////////////////////////////////
# //////////////////////////////////////////
#
#     </script>
#     </script>
# </body>
# </html>
# Out:
# <html>
# <head>
#     <meta charset="utf-8">
#     <title>myProject</title>
#     <!-- import the bundle `lib/echarts.custom.js`. -->
#     <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
# </head>
# <body>
#     <div id="main" style="width: 600px;height:400px;"></div>
#     <script>
#
# ////////////////////////////////////////////////////
#
# 		// Render line chart and components.
# 		echarts.init(document.getElementById('main')).setOption({
# 			title: {text: 'Chart'},
# 			tooltip: {},
# 			toolbox: {
# 				feature: {
# 					dataView: {},
# 					saveAsImage: {
# 						pixelRatio: 2
# 					},
# 					restore: {}
# 				}
# 			},
# 			xAxis: {
# 				type: 'category',
# 				boundaryGap: false,
# 				data: ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
# 			},
# 			yAxis: {
# 				type: 'value'
# 			},
# 			series: [{
# 				data: [820, 932, 901, 934, 1290, 1330, 1320],
# 				type: 'line',
# 				areaStyle: {}
# 			}]
# 		});
#
#
#
#
# ////////////////////////////////////////////////////////
# //////////////////////////////////////////
#
#     </script>
#     </script>
# </body>
# </html>

# %%
# %%html
# <html>
# <head>
#     <meta charset="utf-8">
#     <title>myProject</title>
#     <!-- import the bundle `lib/echarts.custom.js`. -->
#     <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
# </head>
# <body>
#     <div id="main" style="width: 600px;height:400px;"></div>
#     <script>
#
# ////////////////////////////////////////////////////
#
# 		// Render line chart and components.
# 		echarts.init(document.getElementById('main')).setOption({
# 			title: {text: 'Chart'},
# 			tooltip: {
# 				trigger: 'axis',
# 				axisPointer: {
# 					type: 'cross',
# 					label: {
# 						backgroundColor: '#6a7985'
# 					}
# 				}
# 			},
# 			legend: {
# 				data: ['邮件营销', '联盟广告', '视频广告', '直接访问', '搜索引擎']
# 			},
# 			toolbox: {
# 				feature: {
# 					saveAsImage: {}
# 				}
# 			},
# 			grid: {
# 				left: '3%',
# 				right: '4%',
# 				bottom: '3%',
# 				containLabel: true
# 			},
# 			xAxis: [
# 				{
# 					type: 'category',
# 					boundaryGap: false,
# 					data: ['周一', '周二', '周三', '周四', '周五', '周六', '周日']
# 				}
# 			],
# 			yAxis: [
# 				{
# 					type: 'value'
# 				}
# 			],
# 			series: [
# 				{
# 					name: '邮件营销',
# 					type: 'line',
# 					stack: '总量',
# 					areaStyle: {},
# 					data: [120, 132, 101, 134, 90, 230, 210]
# 				},
# 				{
# 					name: '联盟广告',
# 					type: 'line',
# 					stack: '总量',
# 					areaStyle: {},
# 					data: [220, 182, 191, 234, 290, 330, 310]
# 				},
# 				{
# 					name: '视频广告',
# 					type: 'line',
# 					stack: '总量',
# 					areaStyle: {},
# 					data: [150, 232, 201, 154, 190, 330, 410]
# 				},
# 				{
# 					name: '直接访问',
# 					type: 'line',
# 					stack: '总量',
# 					areaStyle: {},
# 					data: [320, 332, 301, 334, 390, 330, 320]
# 				},
# 				{
# 					name: '搜索引擎',
# 					type: 'line',
# 					stack: '总量',
# 					label: {
# 						normal: {
# 							show: true,
# 							position: 'top'
# 						}
# 					},
# 					areaStyle: {},
# 					data: [820, 932, 901, 934, 1290, 1330, 1320]
# 				}
# 			]
# 		});
#
#
#
#
#
# ////////////////////////////////////////////////////////
# //////////////////////////////////////////
#
#     </script>
#     </script>
# </body>
# </html>
# Out:
# <html>
# <head>
#     <meta charset="utf-8">
#     <title>myProject</title>
#     <!-- import the bundle `lib/echarts.custom.js`. -->
#     <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
# </head>
# <body>
#     <div id="main" style="width: 600px;height:400px;"></div>
#     <script>
#
# ////////////////////////////////////////////////////
#
# 		// Render line chart and components.
# 		echarts.init(document.getElementById('main')).setOption({
# 			title: {text: 'Chart'},
# 			tooltip: {
# 				trigger: 'axis',
# 				axisPointer: {
# 					type: 'cross',
# 					label: {
# 						backgroundColor: '#6a7985'
# 					}
# 				}
# 			},
# 			legend: {
# 				data: ['邮件营销', '联盟广告', '视频广告', '直接访问', '搜索引擎']
# 			},
# 			toolbox: {
# 				feature: {
# 					saveAsImage: {}
# 				}
# 			},
# 			grid: {
# 				left: '3%',
# 				right: '4%',
# 				bottom: '3%',
# 				containLabel: true
# 			},
# 			xAxis: [
# 				{
# 					type: 'category',
# 					boundaryGap: false,
# 					data: ['周一', '周二', '周三', '周四', '周五', '周六', '周日']
# 				}
# 			],
# 			yAxis: [
# 				{
# 					type: 'value'
# 				}
# 			],
# 			series: [
# 				{
# 					name: '邮件营销',
# 					type: 'line',
# 					stack: '总量',
# 					areaStyle: {},
# 					data: [120, 132, 101, 134, 90, 230, 210]
# 				},
# 				{
# 					name: '联盟广告',
# 					type: 'line',
# 					stack: '总量',
# 					areaStyle: {},
# 					data: [220, 182, 191, 234, 290, 330, 310]
# 				},
# 				{
# 					name: '视频广告',
# 					type: 'line',
# 					stack: '总量',
# 					areaStyle: {},
# 					data: [150, 232, 201, 154, 190, 330, 410]
# 				},
# 				{
# 					name: '直接访问',
# 					type: 'line',
# 					stack: '总量',
# 					areaStyle: {},
# 					data: [320, 332, 301, 334, 390, 330, 320]
# 				},
# 				{
# 					name: '搜索引擎',
# 					type: 'line',
# 					stack: '总量',
# 					label: {
# 						normal: {
# 							show: true,
# 							position: 'top'
# 						}
# 					},
# 					areaStyle: {},
# 					data: [820, 932, 901, 934, 1290, 1330, 1320]
# 				}
# 			]
# 		});
#
#
#
#
#
# ////////////////////////////////////////////////////////
# //////////////////////////////////////////
#
#     </script>
#     </script>
# </body>
# </html>

# %%
# %%html
# <html>
# <head>
#     <meta charset="utf-8">
#     <title>myProject</title>
#     <!-- import the bundle `lib/echarts.custom.js`. -->
#     <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
# </head>
# <body>
#     <div id="main" style="width: 1280px;height:800px;"></div>
#     <script>
#
# ////////////////////////////////////////////////////
#
#
# 		// Render line chart and components.
# 		var base = +new Date(1968, 9, 3);
# 		var oneDay = 24 * 3600 * 1000;
# 		var date = [];
#
# 		var data = [Math.random() * 300];
#
# 		for (var i = 1; i < 20000; i++) {
# 			var now = new Date(base += oneDay);
# 			date.push([now.getFullYear(), now.getMonth() + 1, now.getDate()].join('/'));
# 			data.push(Math.round((Math.random() - 0.5) * 20 + data[i - 1]));
# 		}
#
# 		// Render line chart and components.
# 		echarts.init(document.getElementById('main')).setOption({
# 			title: {text: 'Chart'},
# 			tooltip: {},
# 			toolbox: {
# 				feature: {
# 					dataView: {},
# 					saveAsImage: {
# 						pixelRatio: 2
# 					},
# 					restore: {}
# 				}
# 			},
# 			tooltip: {
# 				trigger: 'axis',
# 				position: function (pt) {
# 					return [pt[0], '10%'];
# 				}
# 			},
# 			title: {
# 				left: 'center',
# 				text: '大数据量面积图',
# 			},
# 			toolbox: {
# 				feature: {
# 					dataZoom: {
# 						yAxisIndex: 'none'
# 					},
# 					restore: {},
# 					saveAsImage: {}
# 				}
# 			},
# 			xAxis: {
# 				type: 'category',
# 				boundaryGap: false,
# 				data: date
# 			},
# 			yAxis: {
# 				type: 'value',
# 				boundaryGap: [0, '100%']
# 			},
# 			dataZoom: [{
# 				type: 'inside',
# 				start: 0,
# 				end: 10
# 			}, {
# 				start: 0,
# 				end: 10,
# 				handleIcon: 'M10.7,11.9v-1.3H9.3v1.3c-4.9,0.3-8.8,4.4-8.8,9.4c0,5,3.9,9.1,8.8,9.4v1.3h1.3v-1.3c4.9-0.3,8.8-4.4,8.8-9.4C19.5,16.3,15.6,12.2,10.7,11.9z M13.3,24.4H6.7V23h6.6V24.4z M13.3,19.6H6.7v-1.4h6.6V19.6z',
# 				handleSize: '80%',
# 				handleStyle: {
# 					color: '#fff',
# 					shadowBlur: 3,
# 					shadowColor: 'rgba(0, 0, 0, 0.6)',
# 					shadowOffsetX: 2,
# 					shadowOffsetY: 2
# 				}
# 			}],
# 			series: [
# 				{
# 					name: '模拟数据',
# 					type: 'line',
# 					smooth: true,
# 					symbol: 'none',
# 					sampling: 'average',
# 					itemStyle: {
# 						color: 'rgb(255, 70, 131)'
# 					},
# 					areaStyle: {
# 						color: new echarts.graphic.LinearGradient(0, 0, 0, 1, [{
# 							offset: 0,
# 							color: 'rgb(255, 158, 68)'
# 						}, {
# 							offset: 1,
# 							color: 'rgb(255, 70, 131)'
# 						}])
# 					},
# 					data: data
# 				}
# 			]
# 		});
#
#
#
#
#
# ////////////////////////////////////////////////////////
# //////////////////////////////////////////
#
#     </script>
#     </script>
# </body>
# </html>
# Out:
# <html>
# <head>
#     <meta charset="utf-8">
#     <title>myProject</title>
#     <!-- import the bundle `lib/echarts.custom.js`. -->
#     <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
# </head>
# <body>
#     <div id="main" style="width: 1280px;height:800px;"></div>
#     <script>
#
# ////////////////////////////////////////////////////
#
#
# 		// Render line chart and components.
# 		var base = +new Date(1968, 9, 3);
# 		var oneDay = 24 * 3600 * 1000;
# 		var date = [];
#
# 		var data = [Math.random() * 300];
#
# 		for (var i = 1; i < 20000; i++) {
# 			var now = new Date(base += oneDay);
# 			date.push([now.getFullYear(), now.getMonth() + 1, now.getDate()].join('/'));
# 			data.push(Math.round((Math.random() - 0.5) * 20 + data[i - 1]));
# 		}
#
# 		// Render line chart and components.
# 		echarts.init(document.getElementById('main')).setOption({
# 			title: {text: 'Chart'},
# 			tooltip: {},
# 			toolbox: {
# 				feature: {
# 					dataView: {},
# 					saveAsImage: {
# 						pixelRatio: 2
# 					},
# 					restore: {}
# 				}
# 			},
# 			tooltip: {
# 				trigger: 'axis',
# 				position: function (pt) {
# 					return [pt[0], '10%'];
# 				}
# 			},
# 			title: {
# 				left: 'center',
# 				text: '大数据量面积图',
# 			},
# 			toolbox: {
# 				feature: {
# 					dataZoom: {
# 						yAxisIndex: 'none'
# 					},
# 					restore: {},
# 					saveAsImage: {}
# 				}
# 			},
# 			xAxis: {
# 				type: 'category',
# 				boundaryGap: false,
# 				data: date
# 			},
# 			yAxis: {
# 				type: 'value',
# 				boundaryGap: [0, '100%']
# 			},
# 			dataZoom: [{
# 				type: 'inside',
# 				start: 0,
# 				end: 10
# 			}, {
# 				start: 0,
# 				end: 10,
# 				handleIcon: 'M10.7,11.9v-1.3H9.3v1.3c-4.9,0.3-8.8,4.4-8.8,9.4c0,5,3.9,9.1,8.8,9.4v1.3h1.3v-1.3c4.9-0.3,8.8-4.4,8.8-9.4C19.5,16.3,15.6,12.2,10.7,11.9z M13.3,24.4H6.7V23h6.6V24.4z M13.3,19.6H6.7v-1.4h6.6V19.6z',
# 				handleSize: '80%',
# 				handleStyle: {
# 					color: '#fff',
# 					shadowBlur: 3,
# 					shadowColor: 'rgba(0, 0, 0, 0.6)',
# 					shadowOffsetX: 2,
# 					shadowOffsetY: 2
# 				}
# 			}],
# 			series: [
# 				{
# 					name: '模拟数据',
# 					type: 'line',
# 					smooth: true,
# 					symbol: 'none',
# 					sampling: 'average',
# 					itemStyle: {
# 						color: 'rgb(255, 70, 131)'
# 					},
# 					areaStyle: {
# 						color: new echarts.graphic.LinearGradient(0, 0, 0, 1, [{
# 							offset: 0,
# 							color: 'rgb(255, 158, 68)'
# 						}, {
# 							offset: 1,
# 							color: 'rgb(255, 70, 131)'
# 						}])
# 					},
# 					data: data
# 				}
# 			]
# 		});
#
#
#
#
#
# ////////////////////////////////////////////////////////
# //////////////////////////////////////////
#
#     </script>
#     </script>
# </body>
# </html>

# %%
# %%html
# <html>
# <head>
#     <meta charset="utf-8">
#     <title>myProject</title>
#     <!-- import the bundle `lib/echarts.custom.js`. -->
#     <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
# </head>
# <body>
#     <div id="main" style="width: 1024px;height:768px;"></div>
#     <script>
#
# ////////////////////////////////////////////////////
#
# // Generate data
# 		var category = ['市区','万州','江北','南岸','北碚','綦南','长寿','永川','璧山','江津','城口','大足','垫江','丰都','奉节','合川','江津区','开州','南川','彭水','黔江','石柱','铜梁','潼南','巫山','巫溪','武隆','秀山','酉阳','云阳','忠县','川东','检修'];
# 		var dottedBase = [];
# 		var lineData = [18092,20728,24045,28348,32808
# 						,36097,39867,44715,48444,50415
# 						,56061,62677,59521,67560,18092,20728,24045,28348,32808
# 						,36097,39867,44715,48444,50415,36097,39867,44715,48444,50415
# 						,50061,32677,49521,32808];
# 		var barData = [4600,5000,5500,6500,7500
# 						,8500,9900,12500,14000,21500
# 						,23200,24450,25250,33300,4600,5000,5500,6500,7500
# 						,8500,9900,22500,14000,21500,8500,9900,12500,14000,21500
# 						,23200,24450,25250,7500];
# 		var rateData = [];
# 		32808
# 		for (var i = 0; i < 33; i++) {
# 			// var date = i+2001;
# 			// category.push(date)
# 			var rate=barData[i]/lineData[i];
# 			rateData[i] = rate.toFixed(2);
# 		}
#
#
# 		// Render line chart and components.
# 		echarts.init(document.getElementById('main')).setOption({
# 			title: {
# 				text: '增量设备贯通情况-单位',
# 				x: 'center',
# 				y: 0,
# 				textStyle:{
# 					color:'#B4B4B4',
# 					fontSize:16,
# 					fontWeight:'normal',
# 				},
#
# 			},
# 			backgroundColor: '#191E40',
# 			tooltip: {
# 				trigger: 'axis',
# 				backgroundColor:'rgba(255,255,255,0.1)',
# 				axisPointer: {
# 					type: 'shadow',
# 					label: {
# 						show: true,
# 						backgroundColor: '#7B7DDC'
# 					}
# 				}
# 			},
# 			legend: {
# 				data: ['已贯通', '计划贯通','贯通率',],
# 				textStyle: {
# 					color: '#B4B4B4'
# 				},
# 				top:'7%',
# 			},
# 			grid:{
# 				x:'12%',
# 				width:'82%',
# 				y:'12%',
# 			},
# 			xAxis: {
# 				data: category,
# 				axisLine: {
# 					lineStyle: {
# 						color: '#B4B4B4'
# 					}
# 				},
# 				axisTick:{
# 					show:false,
# 				},
# 			},
# 			yAxis: [{
#
# 				splitLine: {show: false},
# 				axisLine: {
# 					lineStyle: {
# 						color: '#B4B4B4',
# 					}
# 				},
#
# 				axisLabel:{
# 					formatter:'{value} ',
# 				}
# 			},
# 				{
#
# 				splitLine: {show: false},
# 				axisLine: {
# 					lineStyle: {
# 						color: '#B4B4B4',
# 					}
# 				},
# 				axisLabel:{
# 					formatter:'{value} ',
# 				}
# 			}],
#
# 			series: [{
# 				name: '贯通率',
# 				type: 'line',
# 				smooth: true,
# 				showAllSymbol: true,
# 				symbol: 'emptyCircle',
# 				symbolSize: 8,
# 				yAxisIndex: 1,
# 				itemStyle: {
# 						normal: {
# 						color:'#F02FC2'},
# 				},
# 				data: rateData
# 			},
#
# 			{
# 				name: '已贯通',
# 				type: 'bar',
# 				barWidth: 10,
# 				itemStyle: {
# 					normal: {
# 						barBorderRadius: 5,
# 						color: new echarts.graphic.LinearGradient(
# 							0, 0, 0, 1,
# 							[
# 								{offset: 0, color: '#956FD4'},
# 								{offset: 1, color: '#3EACE5'}
# 							]
# 						)
# 					}
# 				},
# 				data: barData
# 			},
#
# 			{
# 				name: '计划贯通',
# 				type: 'bar',
# 				barGap: '-100%',
# 				barWidth: 10,
# 				itemStyle: {
# 					normal: {
# 						barBorderRadius: 5,
# 						color: new echarts.graphic.LinearGradient(
# 							0, 0, 0, 1,
# 							[
# 								{offset: 0, color: 'rgba(156,107,211,0.5)'},
# 								{offset: 0.2, color: 'rgba(156,107,211,0.3)'},
# 								{offset: 1, color: 'rgba(156,107,211,0)'}
# 							]
# 						)
# 					}
# 				},
# 				z: -12,
#
# 				data: lineData
# 			},
# 		   ]
# 		});
#
#
#
#
# ////////////////////////////////////////////////////////
# //////////////////////////////////////////
#
#     </script>
#     </script>
# </body>
# </html>
# Out:
# <html>
# <head>
#     <meta charset="utf-8">
#     <title>myProject</title>
#     <!-- import the bundle `lib/echarts.custom.js`. -->
#     <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
# </head>
# <body>
#     <div id="main" style="width: 1024px;height:768px;"></div>
#     <script>
#
# ////////////////////////////////////////////////////
#
# // Generate data
# 		var category = ['市区','万州','江北','南岸','北碚','綦南','长寿','永川','璧山','江津','城口','大足','垫江','丰都','奉节','合川','江津区','开州','南川','彭水','黔江','石柱','铜梁','潼南','巫山','巫溪','武隆','秀山','酉阳','云阳','忠县','川东','检修'];
# 		var dottedBase = [];
# 		var lineData = [18092,20728,24045,28348,32808
# 						,36097,39867,44715,48444,50415
# 						,56061,62677,59521,67560,18092,20728,24045,28348,32808
# 						,36097,39867,44715,48444,50415,36097,39867,44715,48444,50415
# 						,50061,32677,49521,32808];
# 		var barData = [4600,5000,5500,6500,7500
# 						,8500,9900,12500,14000,21500
# 						,23200,24450,25250,33300,4600,5000,5500,6500,7500
# 						,8500,9900,22500,14000,21500,8500,9900,12500,14000,21500
# 						,23200,24450,25250,7500];
# 		var rateData = [];
# 		32808
# 		for (var i = 0; i < 33; i++) {
# 			// var date = i+2001;
# 			// category.push(date)
# 			var rate=barData[i]/lineData[i];
# 			rateData[i] = rate.toFixed(2);
# 		}
#
#
# 		// Render line chart and components.
# 		echarts.init(document.getElementById('main')).setOption({
# 			title: {
# 				text: '增量设备贯通情况-单位',
# 				x: 'center',
# 				y: 0,
# 				textStyle:{
# 					color:'#B4B4B4',
# 					fontSize:16,
# 					fontWeight:'normal',
# 				},
#
# 			},
# 			backgroundColor: '#191E40',
# 			tooltip: {
# 				trigger: 'axis',
# 				backgroundColor:'rgba(255,255,255,0.1)',
# 				axisPointer: {
# 					type: 'shadow',
# 					label: {
# 						show: true,
# 						backgroundColor: '#7B7DDC'
# 					}
# 				}
# 			},
# 			legend: {
# 				data: ['已贯通', '计划贯通','贯通率',],
# 				textStyle: {
# 					color: '#B4B4B4'
# 				},
# 				top:'7%',
# 			},
# 			grid:{
# 				x:'12%',
# 				width:'82%',
# 				y:'12%',
# 			},
# 			xAxis: {
# 				data: category,
# 				axisLine: {
# 					lineStyle: {
# 						color: '#B4B4B4'
# 					}
# 				},
# 				axisTick:{
# 					show:false,
# 				},
# 			},
# 			yAxis: [{
#
# 				splitLine: {show: false},
# 				axisLine: {
# 					lineStyle: {
# 						color: '#B4B4B4',
# 					}
# 				},
#
# 				axisLabel:{
# 					formatter:'{value} ',
# 				}
# 			},
# 				{
#
# 				splitLine: {show: false},
# 				axisLine: {
# 					lineStyle: {
# 						color: '#B4B4B4',
# 					}
# 				},
# 				axisLabel:{
# 					formatter:'{value} ',
# 				}
# 			}],
#
# 			series: [{
# 				name: '贯通率',
# 				type: 'line',
# 				smooth: true,
# 				showAllSymbol: true,
# 				symbol: 'emptyCircle',
# 				symbolSize: 8,
# 				yAxisIndex: 1,
# 				itemStyle: {
# 						normal: {
# 						color:'#F02FC2'},
# 				},
# 				data: rateData
# 			},
#
# 			{
# 				name: '已贯通',
# 				type: 'bar',
# 				barWidth: 10,
# 				itemStyle: {
# 					normal: {
# 						barBorderRadius: 5,
# 						color: new echarts.graphic.LinearGradient(
# 							0, 0, 0, 1,
# 							[
# 								{offset: 0, color: '#956FD4'},
# 								{offset: 1, color: '#3EACE5'}
# 							]
# 						)
# 					}
# 				},
# 				data: barData
# 			},
#
# 			{
# 				name: '计划贯通',
# 				type: 'bar',
# 				barGap: '-100%',
# 				barWidth: 10,
# 				itemStyle: {
# 					normal: {
# 						barBorderRadius: 5,
# 						color: new echarts.graphic.LinearGradient(
# 							0, 0, 0, 1,
# 							[
# 								{offset: 0, color: 'rgba(156,107,211,0.5)'},
# 								{offset: 0.2, color: 'rgba(156,107,211,0.3)'},
# 								{offset: 1, color: 'rgba(156,107,211,0)'}
# 							]
# 						)
# 					}
# 				},
# 				z: -12,
#
# 				data: lineData
# 			},
# 		   ]
# 		});
#
#
#
#
# ////////////////////////////////////////////////////////
# //////////////////////////////////////////
#
#     </script>
#     </script>
# </body>
# </html>

# %%
# %%html

# %%
# %%html

# %%
# %%html

# %%
# %%html

# %%
# %%html

# %%
# %%html

# %%
# %%html

# %%
# %%html
